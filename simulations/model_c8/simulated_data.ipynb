# %%
import pandas as pd
import seaborn as sns
import sys; sys.path.append("./sim_data_analysis")
from mcmc_utils import *
import corner
# %matplotlib inline
# Out:
# /Users/asifzubair/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/asifzubair/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## params used for simulated data ##
# - alpha = 0.131
# - D = 0.86
# - Co = 0.0014
# - N = 128.0
# - K = 5.76
# - K1 = 5.94
# - K2 = 6.35
# - K3 = 7.05

# %%
df = trace_plot("sim_data_analysis/m_c8_1/posteriors_pt_200k_20.csv", suffix = "sim_data_100k")
# Out:
# ****************************************
# *	Iterations: 200000
# *	Burn In: 5000
# *	Thin: 10
# ****************************************
# /Users/asifzubair/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# /Users/asifzubair/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:600: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-8bb33efb7536> in <module>()
# ----> 1 df = trace_plot("sim_data_analysis/m_c8_1/posteriors_pt_200k_20.csv", suffix = "sim_data_100k")
#
# ...

# %%
df = pd.read_table("sim_data_analysis/m_c8_1/posteriors_pt_200k_20.csv")
df.head()
ddf=df[5000::10]

# %%
fig = corner.corner(ddf[["alpha", "D", "Co", "Ns", "K", "K1", "K2", "K3"]], 
              labels = ["alpha", "D", "Co", "Ns", "K", "K1", "K2", "K3"],
             truths = [0.131, 0.86, 0.0014, 128.0, 5.76, 5.94, 6.35, 7.05], )
