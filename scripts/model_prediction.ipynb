# %%
import sys
sys.path.append("../")
import models
from utils import *

BURNIN = 300000
THIN = 100

# %matplotlib inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# # Model A6 #

# %%
m = models.PapaModelA6()
model = "m_a6"
predict = m.predict
data = m.y
df = open_run_subsample("../data/posteriors/" + model + "/posteriors_pt_1M_10.csv", burn_in = BURNIN, thin = THIN)
posterior_sample(data, df, predict, name=model + "sample_posteriors", sample_every=10)

# %% [markdown]
# # Model B7 #

# %%
m = models.PapaModelB7()
model = "m_b7"
predict = m.predict
data = m.y
df = open_run_subsample("../data/posteriors/" + model + "/posteriors_pt_1M_10.csv", burn_in = BURNIN, thin = THIN)
posterior_sample(data, df, predict, name=model + "sample_posteriors", sample_every=10)

# %% [markdown]
# # Model B7r #

# %%
m = models.PapaModelB7r()
model = "m_b7r"
predict = m.predict
data = m.y
df = open_run_subsample("../data/posteriors/" + model + "/posteriors_pt_1M_10.csv", burn_in = BURNIN, thin = THIN)
posterior_sample(data, df, predict, name=model + "sample_posteriors", sample_every=10)

# %% [markdown]
# # Model C8 #

# %%
m = models.PapaModelC8()
model = "m_c8"
predict = m.predict
data = m.y
df = open_run_subsample("../data/posteriors/" + model + "/posteriors_pt_1M_10.csv", burn_in = BURNIN, thin = THIN)
posterior_sample(data, df, predict, name=model + "sample_posteriors", sample_every=10)

# %%
m = models.PapaModelB7()
model = "m_b7"
predict = m.predict
data = m.y
df = open_run_subsample("../data/posteriors/" + model + "/posteriors_pt_1M_10.csv", burn_in = BURNIN, thin = THIN)
posterior_sample(data, df, predict, name=model + "sample_posteriors", sample_every=10)
